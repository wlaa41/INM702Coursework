# %% [markdown]
# # $$ Dijkstra $$

# %%
import numpy as np 
import packages.grid as gd
import packages.grid as gd
import packages.path as pth
import pdb
import sys
sys.path.insert(1, 'D:\AAlearnAA\Study\python')
from rutaul.prnt import pg,pm,pr,py,pb

class vertix():
    def __init__(self,  location:tuple, camefrom , time:int):
        self.location = location
        self.camefrom = camefrom
        self.time = time
    def __repr__(self):
        return f'Vertix a {self.location} -> {self.camefrom} Time: {self.time} '





# ------------------- Creating the random grid
gridsize = (80,50)

d = gd.gridgen(gridsize) # Creating the grid ................ and initializing the nodes distancd to infinity or very high number .. 99999


# gridsize = d.jiktest()
# gridsize = d.fillreallynaughtyLEFTUP()

infin = 999999
d.reachedpointgrid = infin * np.ones(gridsize).astype(int)
gridlength, gridwidth = gridsize
dij_list = []
processed_vertices = []



def findvertix_update(updatever: vertix):
    found= False
    i = 0
    for ver in dij_list:
        if not found:
            if updatever.time < ver.time:
                dij_list.insert(i,updatever)
                if updatever.location == ver.location:
                    dij_list.remove(ver)
                    break
                found = True
        else:
            if updatever.location == ver.location:
                dij_list.remove(ver)
                break
        i +=1

def checkconnection( ver:vertix):
    x,y = ver.location
    lst = []

    def add(X,Y):
        # pdb.set_trace()
        if (X,Y)  != ver.camefrom.location:
            time2reach = ver.time + d.grid[X][Y]
            # pdb.set_trace()
            if time2reach < d.reachedpointgrid[X][Y]:
                if infin == d.reachedpointgrid[X][Y]:
                    d.reachedpointgrid[X][Y] = time2reach
                    lst.append(vertix((X,Y),ver,time2reach))
                else:
                    findvertix_update(vertix((X,Y),ver,time2reach))

                

    if  x- 1 >= 0: # -- CHECK THE GRID DIMENESION Then add the node to ABOVE
        add( x-1,y)

    if x + 1 < gridlength:# -- CHECK THE GRID DIMENESION Then add the node to BELOW
        # pg('CALLING ADD DOWN')
        # pdb.set_trace()
        add(x+1,y)

    if y + 1 < gridwidth:# -- CHECK THE GRID DIMENESION Then add the node to the RIGHT
        # pg('CALLING ADD RIGHT')
        add( x, y+1)
    
    if y - 1 >= 0:  # -- CHECK THE GRID DIMENESION Then add the node to the LEFT
        add(x, y-1)

    return lst

def drawpath(path2start):
    pm(" Dɪᴊᴋsᴛʀᴀ's ᴀʟɢᴏʀɪᴛʜᴍ ")
    grid = d.grid.tolist()
    z = np.ones(gridsize).astype(int)

    import matplotlib
    import matplotlib.pyplot as plt
    from matplotlib.colors import BoundaryNorm
    from matplotlib.ticker import MaxNLocator
    t = 0
    for cell in path2start:
        grid[cell[0]][cell[1]] = '-'
        z[gridlength- 1- cell[0]][cell[1]] = t
        # t+=1
 
    
    x = np.arange(-.5, gridlength+.5, 1)  # len = 11
    y = np.arange(-.5, gridwidth+.5, 1)  # len = 7
    cmap = plt.get_cmap('Spectral')  #
    plt.axis('off')
    # pdb.set_trace()

    plt.style.use('dark_background')
    z.reshape(gridwidth,gridlength)
    plt.pcolormesh(y, x, z, cmap=cmap, edgecolor='black',snap= True)

    # pdb.set_trace()

    for row in range(0, gridlength):
        for cell in range(0, gridwidth):

            plt.text(cell, row, d.grid[gridlength - row-1][cell], color='white', ha='center', va='center', fontsize=10)
    # pdb.set_trace()

def dijkstra():
    # The algorithm will start from 0,0
    # for row in range(0, gridlength):
    #     for cell in row:
    #         conectedvertices vertixConection()
   


        # map(lambda x: lst.remove(x) if x.comefrom == ver.location , lst)
    

    d.reachedpointgrid[0][0] = d.grid[0][0]

    dij_list.append(vertix((0,0), vertix((-1,-1),None,0) , d.grid[0][0]))
    while len(dij_list) > 0:
        if dij_list[0].location == (gridlength-1,gridwidth-1):
            py(dij_list)
            pr('Shortest Path Found')
            loop = True
            path = '' + str(dij_list[0].location)
            pointer = dij_list[0]
            path2start = [dij_list[0].location]
            while loop:

                path2start.append(pointer.camefrom.location)

                if pointer.camefrom.location == (0,0):
                    path = path +" <- "+ str(pointer.camefrom.location)
                    drawpath(path2start)
                    break
                else:
                    path = path +" <- " +str(pointer.camefrom.location)
                    pointer = pointer.camefrom
            pm(path)
            break
        else:
            connectedvertices = checkconnection(dij_list[0])
            
            i = 1
            notinserted = True
            # pr(d.reachedpointgrid)
            for ver in connectedvertices:
                notinserted = True
                for i in range(1,len(dij_list)):
                    if ver.time < dij_list[i].time:
                        dij_list.insert( i, ver)
                        notinserted = False
                        break
                if notinserted:
                    dij_list.append(ver)
            
            connectedvertices = []
            # pg(d.reachedpointgrid)
            processed_vertices.append(dij_list.pop(0))
            
        
        
pb(d.grid)
dijkstra()
# Out:
# ........... 🆂  🆃  🅰   🆁  🆃 ...........
# [[1 0 9 ... 5 6 1]
#  [7 9 1 ... 6 2 2]
#  [8 7 0 ... 5 9 4]
#  ...
#  [7 4 1 ... 9 3 0]
#  [2 3 5 ... 7 5 9]
#  [7 4 2 ... 9 5 3]]
# [Vertix a (79, 49) -> Vertix a (78, 49) -> Vertix a (77, 49) -> Vertix a (76, 49) -> Vertix a (75, 49) -> Vertix a (74, 49) -> Vertix a (74, 48) -> Vertix a (73, 48) -> Vertix a (73, 47) -> Vertix a (72, 47) -> Vertix a (72, 46) -> Vertix a (71, 46) -> Vertix a (71, 45) -> Vertix a (70, 45) -> Vertix a (69, 45) -> Vertix a (69, 46) -> Vertix a (68, 46) -> Vertix a (67, 46) -> Vertix a (66, 46) -> Vertix a (65, 46) -> Vertix a (64, 46) -> Vertix a (63, 46) -> Vertix a (63, 47) -> Vertix a (62, 47) -> Vertix a (62, 48) -> Vertix a (61, 48) -> Vertix a (61, 49) -> Vertix a (60, 49) -> Vertix a (59, 49) -> Vertix a (59, 48) -> Vertix a (58, 48) -> Vertix a (57, 48) -> Vertix a (57, 47) -> Vertix a (57, 46) -> Vertix a (56, 46) -> Vertix a (56, 45) -> Vertix a (56, 44) -> Vertix a (55, 44) -> Vertix a (54, 44) -> Vertix a (54, 43) -> Vertix a (53, 43) -> Vertix a (52, 43) -> Vertix a (52, 42) -> Vertix a (52, 41) -> Vertix a (52, 40) -> Vertix a (51, 40) -> Vertix a (50, 40) -> Vertix a (50, 39) -> Vertix a (50, 38) -> Vertix a (49, 38) -> Vertix a (49, 37) -> Vertix a (48, 37) -> Vertix a (47, 37) -> Vertix a (46, 37) -> Vertix a (45, 37) -> Vertix a (44, 37) -> Vertix a (43, 37) -> Vertix a (43, 36) -> Vertix a (42, 36) -> Vertix a (41, 36) -> Vertix a (40, 36) -> Vertix a (40, 35) -> Vertix a (40, 34) -> Vertix a (40, 33) -> Vertix a (39, 33) -> Vertix a (39, 32) -> Vertix a (38, 32) -> Vertix a (38, 31) -> Vertix a (37, 31) -> Vertix a (37, 30) -> Vertix a (37, 29) -> Vertix a (36, 29) -> Vertix a (36, 28) -> Vertix a (36, 27) -> Vertix a (35, 27) -> Vertix a (34, 27) -> Vertix a (33, 27) -> Vertix a (32, 27) -> Vertix a (31, 27) -> Vertix a (31, 26) -> Vertix a (31, 25) -> Vertix a (30, 25) -> Vertix a (30, 24) -> Vertix a (30, 23) -> Vertix a (30, 22) -> Vertix a (29, 22) -> Vertix a (29, 21) -> Vertix a (28, 21) -> Vertix a (28, 20) -> Vertix a (28, 19) -> Vertix a (27, 19) -> Vertix a (27, 18) -> Vertix a (27, 17) -> Vertix a (26, 17) -> Vertix a (25, 17) -> Vertix a (25, 16) -> Vertix a (25, 15) -> Vertix a (24, 15) -> Vertix a (24, 14) -> Vertix a (24, 13) -> Vertix a (24, 12) -> Vertix a (24, 11) -> Vertix a (23, 11) -> Vertix a (22, 11) -> Vertix a (21, 11) -> Vertix a (21, 10) -> Vertix a (20, 10) -> Vertix a (19, 10) -> Vertix a (18, 10) -> Vertix a (17, 10) -> Vertix a (16, 10) -> Vertix a (16, 9) -> Vertix a (16, 8) -> Vertix a (15, 8) -> Vertix a (15, 7) -> Vertix a (14, 7) -> Vertix a (13, 7) -> Vertix a (13, 6) -> Vertix a (12, 6) -> Vertix a (11, 6) -> Vertix a (11, 5) -> Vertix a (10, 5) -> Vertix a (9, 5) -> Vertix a (8, 5) -> Vertix a (7, 5) -> Vertix a (6, 5) -> Vertix a (6, 4) -> Vertix a (5, 4) -> Vertix a (4, 4) -> Vertix a (3, 4) -> Vertix a (3, 3) -> Vertix a (2, 3) -> Vertix a (2, 2) -> Vertix a (1, 2) -> Vertix a (1, 1) -> Vertix a (0, 1) -> Vertix a (0, 0) -> Vertix a (-1, -1) -> None Time: 0  Time: 1  Time: 1  Time: 10  Time: 11  Time: 11  Time: 11  Time: 12  Time: 13  Time: 16  Time: 16  Time: 22  Time: 24  Time: 25  Time: 31  Time: 39  Time: 42  Time: 43  Time: 43  Time: 44  Time: 49  Time: 51  Time: 52  Time: 53  Time: 60  Time: 60  Time: 60  Time: 60  Time: 61  Time: 67  Time: 69  Time: 70  Time: 70  Time: 70  Time: 70  Time: 70  Time: 71  Time: 75  Time: 77  Time: 82  Time: 83  Time: 84  Time: 85  Time: 87  Time: 96  Time: 97  Time: 97  Time: 100  Time: 104  Time: 104  Time: 105  Time: 107  Time: 110  Time: 111  Time: 111  Time: 113  Time: 113  Time: 114  Time: 118  Time: 121  Time: 122  Time: 124  Time: 130  Time: 132  Time: 132  Time: 132  Time: 138  Time: 143  Time: 146  Time: 150  Time: 150  Time: 150  Time: 151  Time: 152  Time: 152  Time: 153  Time: 161  Time: 161  Time: 162  Time: 163  Time: 163  Time: 164  Time: 165  Time: 165  Time: 169  Time: 171  Time: 178  Time: 180  Time: 180  Time: 180  Time: 181  Time: 181  Time: 183  Time: 185  Time: 186  Time: 189  Time: 192  Time: 195  Time: 199  Time: 200  Time: 202  Time: 204  Time: 207  Time: 209  Time: 211  Time: 212  Time: 212  Time: 212  ...
# Shortest Path Found
#  Dɪᴊᴋsᴛʀᴀ's ᴀʟɢᴏʀɪᴛʜᴍ
# (79, 49) <- (78, 49) <- (77, 49) <- (76, 49) <- (75, 49) <- (74, 49) <- (74, 48) <- (73, 48) <- (73, 47) <- (72, 47) <- (72, 46) <- (71, 46) <- (71, 45) <- (70, 45) <- (69, 45) <- (69, 46) <- (68, 46) <- (67, 46) <- (66, 46) <- (65, 46) <- (64, 46) <- (63, 46) <- (63, 47) <- (62, 47) <- (62, 48) <- (61, 48) <- (61, 49) <- (60, 49) <- (59, 49) <- (59, 48) <- (58, 48) <- (57, 48) <- (57, 47) <- (57, 46) <- (56, 46) <- (56, 45) <- (56, 44) <- (55, 44) <- (54, 44) <- (54, 43) <- (53, 43) <- (52, 43) <- (52, 42) <- (52, 41) <- (52, 40) <- (51, 40) <- (50, 40) <- (50, 39) <- (50, 38) <- (49, 38) <- (49, 37) <- (48, 37) <- (47, 37) <- (46, 37) <- (45, 37) <- (44, 37) <- (43, 37) <- (43, 36) <- (42, 36) <- (41, 36) <- (40, 36) <- (40, 35) <- (40, 34) <- (40, 33) <- (39, 33) <- (39, 32) <- (38, 32) <- (38, 31) <- (37, 31) <- (37, 30) <- (37, 29) <- (36, 29) <- (36, 28) <- (36, 27) <- (35, 27) <- (34, 27) <- (33, 27) <- (32, 27) <- (31, 27) <- (31, 26) <- (31, 25) <- (30, 25) <- (30, 24) <- (30, 23) <- (30, 22) <- (29, 22) <- (29, 21) <- (28, 21) <- (28, 20) <- (28, 19) <- (27, 19) <- (27, 18) <- (27, 17) <- (26, 17) <- (25, 17) <- (25, 16) <- (25, 15) <- (24, 15) <- (24, 14) <- (24, 13) <- (24, 12) <- (24, 11) <- (23, 11) <- (22, 11) <- (21, 11) <- (21, 10) <- (20, 10) <- (19, 10) <- (18, 10) <- (17, 10) <- (16, 10) <- (16, 9) <- (16, 8) <- (15, 8) <- (15, 7) <- (14, 7) <- (13, 7) <- (13, 6) <- (12, 6) <- (11, 6) <- (11, 5) <- (10, 5) <- (9, 5) <- (8, 5) <- (7, 5) <- (6, 5) <- (6, 4) <- (5, 4) <- (4, 4) <- (3, 4) <- (3, 3) <- (2, 3) <- (2, 2) <- (1, 2) <- (1, 1) <- (0, 1) <- (0, 0)
